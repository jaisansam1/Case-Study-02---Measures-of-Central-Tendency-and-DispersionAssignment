# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('StudentsPerformance.csv')
df = pd.DataFrame(data)

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # 1. Number of Male and Female Students

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
check = df['parental level of education'].value_counts()
print(check)
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.countplot(y='parental level of education', hue='race/ethnicity', data=data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='parental level of education'>

# %% [markdown]
# # 2. Ethnic Group C has the most education while Ethnic Group C has the least education.

# %%
sns.countplot(y='parental level of education', data=data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='parental level of education'>

# %%
grouped_data = data.groupby(["gender", "math score"])

# %%
grouped_data.head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# 5    female        group B                 high school  free/reduced
# 6    female        group B            some high school  free/reduced
# 7    female        group D          associate's degree  free/reduced
# 8    female        group D            some high school  free/reduced
# 9    female        group C                 high school      standard
# 10   female        group C            some high school  free/reduced
# 11   female        group D           bachelor's degree  free/reduced
# 12   female        group B            some high school      standard
# ...

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
s = data.groupby('gender')

# %%
s.head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# 518    male        group C                 high school  free/reduced
# 519    male        group A                some college  free/reduced
# 520    male        group B                 high school  free/reduced
# 521    male        group E            some high school      standard
# 522    male        group B                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none           0             17             10
# ...

# %%
check = data[['gender','math score','reading score','writing score']]

# %%
checkf = check.loc[check['gender'] == 'female']
checkm = check.loc[check['gender'] == 'male']

# %%
pd.option_context('display.max_rows', None, 'display.max_columns', None)

# %%
checkf.describe()
# Out:
#        math score  reading score  writing score
# count  518.000000     518.000000     518.000000
# mean    63.376448      72.590734      72.467181
# std     16.029928      14.411018      14.844842
# min      0.000000      17.000000      10.000000
# 25%     54.000000      63.250000      64.000000
# 50%     65.000000      73.000000      74.000000
# 75%     74.000000      83.000000      82.000000
# max    100.000000     100.000000     100.000000

# %%
checkm.describe()
# Out:
#        math score  reading score  writing score
# count  482.000000     482.000000     482.000000
# mean    68.821577      65.545643      63.446058
# std     14.556411      14.149594      14.227225
# min     27.000000      23.000000      15.000000
# 25%     59.000000      56.000000      53.000000
# 50%     69.000000      66.000000      64.000000
# 75%     79.000000      76.000000      74.000000
# max    100.000000     100.000000     100.000000

# %% [markdown]
# # 3a. Females Score the most in Reading and Writing
# # 3b. Males Score the most in Maths
#
# # 4a. Scoring Variation Math Score - There is more variation in female scoring as the standard deviation is wide especially in maths scores

# %%
TPdata = data[['test preparation course','math score','reading score','writing score']]

# %%
pd.set_option('display.max_rows', None)

# %%
print(TPdata)
# Out:
#     test preparation course  math score  reading score  writing score
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# 5                 completed          23             44             36
# 6                      none          24             38             27
# 7                      none          26             31             38
# 8                      none          19             34             32
# 9                      none          29             29             30
# 10                completed          29             40             44
# 11                     none          29             41             47
# ...

# %%
sns.pairplot(data=TPdata, hue= 'test preparation course', height = 5)

# %% [markdown]
# # 4b. PLTS clearly show that Candidates scored better when they have not undergone the TEST PREPARATION COURSE
#
# # Need to check the effectiveness and the duration of time being spent on the course
#
# #  Scoring variation Test Preparation Course:  in males is comparitively less and more stable. Standard deviation is narrow and almost similar in all three test areas

# %%
datamathscore =data[['math score']]

# %%
datamathscore=datamathscore.sort_values('math score', ascending=False)
print(datamathscore)
# Out:
#      math score
# 999         100
# 996         100
# 515         100
# 517         100
# 516         100
# 997         100
# 998         100
# 995          99
# 513          99
# 514          99
# 994          98
# 993          98
# 512          98
# 992          97
# 991          97
# 989          97
# 510          97
# 511          97
# 990          97
# 509          96
# 508          96
# 988          96
# 507          95
# 987          95
# 505          94
# 506          94
# 982          94
# 983          94
# 985          94
# 986          94
# 984          94
# 504          93
# 503          93
# 980          93
# 981          93
# 978          92
# 979          92
# 499          92
# 502          92
# 501          92
# 500          92
# 973          91
# 497          91
# 498          91
# 975          91
# 977          91
# 974          91
# 972          91
# 976          91
# 971          91
# 969          90
# 967          90
# 968          90
# 495          90
# ...

# %% [markdown]
# # 5. Index numbers of the top 25% students in descending order on the basis of maths scores

# %%
datamathscore.nlargest(250,'math score')
# Out:
#      math score
# 999         100
# 996         100
# 515         100
# 517         100
# 516         100
# 997         100
# 998         100
# 995          99
# 513          99
# 514          99
# 994          98
# 993          98
# 512          98
# 992          97
# 991          97
# 989          97
# 510          97
# 511          97
# 990          97
# 509          96
# 508          96
# 988          96
# 507          95
# 987          95
# 505          94
# 506          94
# 982          94
# 983          94
# 985          94
# 986          94
# 984          94
# 504          93
# 503          93
# 980          93
# 981          93
# 978          92
# 979          92
# 499          92
# 502          92
# 501          92
# 500          92
# 973          91
# 497          91
# 498          91
# 975          91
# 977          91
# 974          91
# 972          91
# 976          91
# 971          91
# 969          90
# 967          90
# 968          90
# 495          90
# ...
